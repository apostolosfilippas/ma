# %% [markdown]
# ---
#
# ### 🎓 **Professor**: Apostolos Filippas
#
# ### 📘 **Class**: AI and Data-Driven Marketplaces
#
# ### 📋 **Topic**: Homework 5
#
# 🚫 **Note**: You are not allowed to share the contents of this notebook with anyone outside this class without written permission by the professor.
#
# ---

# %% [markdown]
# > **Before you begin:** [Update your course files and Python environment safely.](https://github.com/apostolosfilippas/ma/blob/main/assets/before-you-begin.md)

# %% [markdown]
# In this homework, you will -- once again-- assume the role of a product manager for a large online marketplace! You are tasked with evaluating the proposal, execution, and results of a marketplace experiment. You will use synthetic data simulated from a real marketplace experiment.

# %% [markdown]
# **Please follow the instructions below very carefully**

# %% [markdown]
# #### **1. The informational content of public and private feedback**
# In your online labor market, employers (users who post jobs) transact with workers (freelancers). For example, se [Upwork](http://upwork.com/), [Taskrabbit](http://taskrabbit.com/), [Freelancer](https://www.freelancer.com/), and so on.
#
# Unfortunately, your public feedback scores suffer from severe reputation inflation (see HW1, Lecture 5, and practically any peer-to-peer marketplace).  To examine the consequences of reputation inflation, the platform introduced a new private feedback feature: in addition to giving public feedback, employers were also asked for “private” feedback. The private feedback was elicited by asking employers “Would you hire this worker again in the future?” after each transaction, to which the employers were asked to select one of four pre-populated answers. Importantly, the platform told the employers that this private feedback would be kept anonymous (the identity of the rating employer would not be shared with anyone) and hidden (the feedback would only be collected by the platform for internal evaluation purposes, and not shared with the other users, including future employers or the rated worker).
#
# Because of this platform intervention, you now have access to both private and public feedback information for the same employer-worker transaction.  Download the data from [this link](https://github.com/apostolosfilippas/ma/blob/56a5577529384c4dba28c4adc9da0f9fa79a51e5/data/ma-homework-3-private-by-public.csv). Notice that public feedback, which is given as a numerical score, is also given in “bin” format. Each bin simply represents the range in which the score is contained. For example, all scores from 1 to 1.25 belong to the same bin [1,1.25].
#
# **Question 1.1** (5 points)
#
# What were the possible answers to the private feedback question? What percentage of transactions received each private feedback answer?
#
# **Question 1.2** (20 points)
#
# Plot the distribution of public feedback scores for transactions that received the same answer to the private feedback question. Hint: You need to produce 4 plots. The distribution of public feedback scores for all transactions that received a private “Definitely not,” the distribution of public feedback scores for all transactions that received a private “Probably Not,”... One way to plot the distribution is to create histograms of public feedback score bins (x-axis) and the percentage of public feedback scores within each bin (y-axis). Of course, there are other ways. (Bonus: Use faceting to combine the four plots into one plot +5 points)
#
# **Question 1.3** (15 points)
#
# Do you notice anything peculiar in your plots? Explain.

# %% [markdown]
# #### **2. Experiment proposal: Revealing private feedback scores**
#
# Upon realizing that the private feedback scores may contain more information for employers to take advantage of in their hiring process, the product team decided to run an experiment to evaluate whether having the more informative private feedback information would allow employers to make better hires. As such, employers would be allocated to one of two experimental groups: (i) a control group, which would have the status quo hiring experience, and (ii) a treatment group, where employers treated employers would be shown the percentage of previous employers who stated they would hire each freelancer again in the future in their private feedback, in addition to all information shown to control group employers.
#
# **Question 2.1** (15 points)
#
# What are some potential problems that would make interpreting the experimental results hard in our setting? Use the “lies” checklist provided in Lecture 8, or come up with your own (plausible) points!
#
# **Question 2.2** (15 points)
#
# Another PM suggested that we should use workers instead of employers as the randomization unit, that is, to randomly select workers whose private feedback would then be viewable by all employers (treatment) and workers whose private feedback would not be viewable by any employer (control). Would that be better or worse than using employers as the randomization unit? Why?

# %% [markdown]
# #### **3. Evaluation: Analyzing the experiment**
#
# The company decided to run the originally proposed experiment. Here is [the data](https://github.com/apostolosfilippas/ma/blob/56a5577529384c4dba28c4adc9da0f9fa79a51e5/data/ma-homework-3-experiment-users.csv) of the users that were randomly assigned to the control and treatment groups for the experiment. The attributes of your data are:
#
# - `user`: an id for each user
# - `treatment`: whether the user was assigned to treatment (1) or to control (0)
# - `num_applications`: the number of applications the employer has received before the experiment
# - `num_hires`: the number of workers the employer has hired before the experiment
# - `prior_spend`: the amount of money the employer has spent before the experiment
# - `prior_openings`: the amount of jobs the employer has posted on the platform before the experiment
#
# **Question 3.1** (10 points)
#
# What is the sample size? Was the randomized assignment performed correctly? (tip: do several balance tests)
#
# You now want to examine how the new information affected the hiring process in the platform. Here is [the data](https://github.com/apostolosfilippas/ma/blob/main/data/ma-homework-3-experiment-hiring.csv) containing only low-quality workers’ applications to job openings, and the application’s eventual outcomes (low-quality workers are defined as those with a private feedback score ≤ 0.5). The data attributes are:
#
# - `treatment`: whether the employer could see the applying worker’s private feedback
# - `evaluated`: whether the worker’s application was evaluated by the employer
# - `interviewed`: whether the worker was interviewed by the employer
# - `hired`: whether the worker was hired by the employer
#
# **Question 3.2** (20 points)
#
# Analyze the experiment by comparing, across the two groups, the following outcomes: (i) the probability that a low-quality workers’ application is evaluated, (ii) the probability that a low-quality worker is interviewed, and (iii) the probability that a low-quality worker is hired. Visualize and comment on your results.

# %% [markdown]
# #### **4. Platform-wide rollout**
#
# After the apparent success of the experiment, the platform decided to start publicly revealing the private feedback information, by showing in each worker’s profile the percentage of previous employers that would hire the worker again in the future. The rationale behind this decision is that employers would now have access to a more informative kind of feedback, and hence make better hiring decisions.
#
# **Bonus question** (up to +20 points)
#
# What are some challenges in a platform-wide rollout? What are some possible solutions? Focus on whether the new, more informative feedback will be the solution to the platform’s reputation inflation woes.
#
# # Deliverables and grading
#
# Submit the following on blackboard:
#
# 1. **your clearly-commented code (submission format: only .py or .ipynb files accepted)** Note: The submitted code has to do something for you to receive a non-zero grade for this homework. Please only submit a single, clearly-commented .py or .ipynb file
#
# 2. **a report outlining the results of your analysis (submission format: only .pdf files accepted).** Note: In creating the report, keep in mind that the goal of this assignment is to simulate a situation where you report your results to the C-suite. Toward that end, good reports are not unnecessarily lengthy, but rather present the results of the analyses through succinct wording and great figures, as appropriate.
#
# 3. **Collaboration:** This assignment can be undertaken by groups of up to 3 people. However, if you want to go solo, by all means go ahead. Only one member of each team has to submit the report and the code; please clearly indicate the names and emails of all members of the team at the top of the report.
