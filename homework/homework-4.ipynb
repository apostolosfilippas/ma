# %% [markdown]
# ---
#
# ### 🎓 **Professor**: Apostolos Filippas
#
# ### 📘 **Class**: AI and Data-Driven Marketplaces
#
# ### 📋 **Topic**: Homework 4
#
# 🚫 **Note**: You are not allowed to share the contents of this notebook with anyone outside this class without written permission by the professor.
#
# ---

# %% [markdown]
# > **Before you begin:** [Update your course files and Python environment safely.](https://github.com/apostolosfilippas/ma/blob/main/assets/before-you-begin.md)

# %% [markdown]
# In this homework, you will assume the role of an investor/consultant/head of product, who is specializing in two-sided online marketplaces. Your task is to analyze the product characteristics and market design of *two* marketplaces, to argue why they “work,” and to suggest improvements.

# %% [markdown]
# ## 1. Market assignment
#
# You have to review 2 online marketplaces
#
# - Go to [this list](https://a16z.com/marketplace-100/)
#
# - You have been assigned marketplaces XY and XY+50, where XY are the last 2 digits of your Fordham Identification number (begins with A, followed by 8 numbers). For example, if XY=70, then your assigned marketplaces are 70 and 20 -- because 70+50 = 120, and there are 100 markets on the list. If XY=00, assume that XY==01 instead.

# %% [markdown]
# ## 2. Marketplace surveys (60 pts)
#
# For each of your assigned marketplaces, fill in this [marketplace survey](https://docs.google.com/document/d/1-7-yzqPnzs8VJDBFK3KmPeIZGyiIHDK7WtxemPle_rQ/edit?usp=sharing).
#
# - Here is a [completed survey example](https://docs.google.com/document/d/1M332Jlz609RKYQ50V4xuseJRRwlrJ_JA661HWJQhS4Y/edit?usp=sharing) on Uber.

# %% [markdown]
# ## 3. Essays (40 pts)
#
# Write two short essays for the two marketplaces you were assigned.
#
# - Begin the essay by describing what the marketplace does.
#
# - Focus on one important market mechanism that adds value compared to a Craigslist-like “light-touch” market. Describe what problem this market mechanism solves, and why other potential mechanisms would not be as efficient in solving that problem.
#
# - Be succinct -- I’d suggest not exceeding 4 pages per essay
#
# ***Note:*** Do your best to collect accurate information on your assigned marketplaces. This includes registering and using the marketplace, reading articles, ... If your assigned marketplaces no longer exist **or** if for some other reason you cannot complete your survey, then please pick another marketplace based on your interests and send us an email.

# %% [markdown]
# ## 4. Improve your marketplace (bonus)
#
# If you think that some market mechanisms are suboptimal (or missing) from your assigned marketplace, explain why you think so, suggest alternative mechanisms, and argue why they would be better.
#
# - We will review your suggestions, and award you a bonus accordingly [+*5pts/suggestion, limit: +15pts*]
#
# - Put some thought into this. You may come up with something really good, in which case we can reach out to the marketplace itself and see what they think!
#
# - Be succinct -- I’d suggest not exceeding 2 pages per suggestion, unless you *really* need more space.

# %% [markdown]
# ## Deliverables and grading
#
# Submit the following items on blackboard:
#
# 1. Your completed marketplace surveys (submission format: .pdf)
#
#    Note: If your name is “Jill Sanders” and you were assigned Facebook and Snap, then your deliverables should be *Jill\_Sanders\_Facebook.pdf* and *Jill\_Sanders\_Snap.pdf*
#
# 2. Your essay (submission format: only .pdf files accepted)
#
#    Note: Your essay should be named *Jill\_Sanders\_Essay.pdf*
