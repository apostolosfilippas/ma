# %% [markdown]
# ---
#
# ### 🎓 **Professor**: Apostolos Filippas
#
# ### 📘 **Class**: AI and Data-Driven Marketplaces
#
# ### 📋 **Topic**: Homework 3
#
# 🚫 **Note**: You are not allowed to share the contents of this notebook with anyone outside this class without written permission by the professor.
#
# ---

# %% [markdown]
# > **Before you begin:** [Update your course files and Python environment safely.](https://github.com/apostolosfilippas/ma/blob/main/BEFORE_YOU_BEGIN.md)

# %% [markdown]
# In this homework, you will assume the role of a product manager of a large online marketplace. You are tasked with exploring its reputation system data to extract actionable business insights. You will use synthetic data simulated from real marketplace data. Each row represents a review that a renter gave a car.
#
# The work you have to do is **very similar** to what we covered in class; make sure you have understood this material before proceeding.

# %% [markdown]
# **Please follow the instructions below very carefully**

# %% [markdown]
# **1. Downloading and opening the data** (20 points)
#
# Download the [CSV file](https://github.com/apostolosfilippas/ma/blob/main/data/ma-homework-1-ratings.csv) by clicking **Download raw file**. If you cloned the repository, it is already in `data/ma-homework-1-ratings.csv`.
#
# - Open the file in Python and save it in a DataFrame called `df_ratings`.
# - The column `Unnamed: 0` is a saved row index, not an attribute of a review. Ignore it in your analysis.

# %% [markdown]
# **2. Understanding your data** (20 points)
#
# You now have to “profile” your data—to understand what it contains and how much data you have. Use Python to answer the following:
#
# - How many observations are there in your data?
# - How many unique renters?
# - How many unique cars?
# - How many unique, non-missing sources? What does each label mean? The `source` column identifies the platform used to submit the review.
# - What score does each `score_numeric` correspond to?
# - Briefly describe what your data is about. Using a table, describe what each column means, excluding the saved row index.

# %% [markdown]
# **3. Analyzing your data** (30 points)
#
# - **Most common review source.** For this question only, exclude reviews with a missing source using `df_ratings.dropna(subset=["source"])`. Pandas reads the blank source fields as missing values, not empty strings. Keep `df_ratings` unchanged for the other questions. How many reviews were submitted through each platform? Which source has the most reviews, and what might that mean for the business? These are shares of reviews, not necessarily shares of users or bookings. Bonus: find the percentage of reviews submitted through each platform, using only reviews with a known source as the denominator. (up to +5 pts)
# - **Most reviewed cars and most active reviewers.** What are the IDs of the 10 cars with the most reviews? What are the IDs of the 10 renters who gave the most ratings? Show the review counts alongside the IDs. Review counts measure review activity, not necessarily bookings or popularity. Bonus: create a column with each car's rank, starting at 1 for the car with the most reviews. Cars with equal counts share a rank, and the next rank is skipped—for example, 1, 2, 2, 4. (up to +5 pts)
# - **Review volume each month.** Using all reviews, how many were posted each month? Suggest a possible explanation for the pattern and describe what additional evidence you would need to check it. These data alone cannot establish the cause.

# %% [markdown]
# **4. Visualization** (30 points)
#
# - **Distribution of ratings.** Make a histogram of `score_numeric`, with one bin centered on each rating from 1 to 5. Save it in a PDF called "ratings_hist.pdf". What do you observe? What is a possible interpretation? A concentration of high ratings does not, by itself, establish that reviews are dishonest or inflated. Bonus: Make the plot as visually pleasing as possible (up to +5 pts)
# - **Evolution of ratings.** Using all reviews, make a plot with each month on the x-axis and that month's average numerical rating on the y-axis. Put the months in chronological order. Save it in a PDF called "ratings_evolution.pdf". What do you observe? Suggest a possible explanation and what evidence would help distinguish it from alternatives. A change in the average could reflect different renters or cars being reviewed, rather than a change in quality.
# - **Bonus:** For extra points, make the plot as visually pleasing as possible. (up to +5 pts)

# %% [markdown]
# # Deliverables and grading
#
# Submit the following on blackboard:
#
# **1. your Python code (submission format: only .py or .ipynb files accepted).**
#
# Note: The submitted code has to do *something* for you to receive a non-zero grade for this homework. Please only submit a single clearly-commented .py or .ipynb file
#
# **2. a report outlining the results of your analysis (submission format: only .pdf files accepted).**
#
# Note: In creating the report, keep in mind that the goal of this assignment is to simulate a situation where you report your results to the C-suite. Toward that end, good reports are not unnecessarily lengthy, but rather present the results of the analyses through succinct wording and great figures, as appropriate.
#
# **Collaboration**
#
# You are free to talk to other students about this assignment and help one another. In fact, I encourage you to do so -- peer learning is a powerful learning tool. However, this is not a group assignment. You must submit your own work and create your own report. You may use a coding agent to help write, debug, or explain code, but you must check the results and be able to explain what your code does and what your findings mean. Do not submit another student's code or report. If you have any questions, please read course policies #5 and #7 in the syllabus; if you still have questions, contact the instructor!
