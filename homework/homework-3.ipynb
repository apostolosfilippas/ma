# %% [markdown]
# ---
#
# ### 🎓 **Professor**: Apostolos Filippas
#
# ### 📘 **Class**: AI and Data-Driven Marketplaces
#
# ### 📋 **Topic**: Homework 3
#
# 🚫 **Note**: You are not allowed to share the contents of this notebook with anyone outside this class without written permission by the professor.
#
# ---

# %% [markdown]
# > **Before you begin, get the latest course files:**
# >
# > - **If you cloned the repository:** Open the `ma` folder in VS Code, choose **Terminal → New Terminal**, type `git pull`, and press Enter. You can also run this command in your computer's terminal from inside the `ma` folder.
# > - **If you need to download the homework:** Open [Homework 3 on GitHub](https://github.com/apostolosfilippas/ma/blob/main/homework/homework-3.ipynb), click **Download raw file** (the download arrow), and open the downloaded notebook in VS Code.

# %% [markdown]
# In this homework, you will assume the role of a product manager of a large online marketplace. You are tasked performing an exploratory data analysis on the reputation system data of the online marketplace, in order to extract actionable business insights. You will use synthetic data simulated from real marketplace data.
#
# The work you have to do is **very similar** to what we covered in class; make sure you have understood this material before proceeding.

# %% [markdown]
# **Please follow the instructions below very carefully**

# %% [markdown]
# **1. Downloading and opening the data** (20 points)
#
# Download the data from this <a href="https://github.com/apostolosfilippas/ma/blob/7088a60b0bf1caf8a7cff2eb7f304037ba97fad4/data/ma-homework-1-ratings.csv" target="_blank">link</a>.
# - The data is in CSV format.
# - Open the file, and save it in a variable called `df_ratings`.

# %% [markdown]
# **2. Understanding your data** (20 points)
#
# You now have to “profile” your data -- to understand what exactly the data that you have is about, how much data you have, and so on. Use Python to answer the following:
# - How many observations are there in your data?
# - How many unique renters?
# - How many unique cars?
# - How many unique sources? What does “source” mean?
# - What score does each score_numeric correspond to?
# - Briefly describe what your data is about. Using a table, describe what each column means.

# %% [markdown]
# **3. Analyzing your data** (30 points)
# - **Most popular source.** Exclude all ratings that do not have a source from your data --- those ratings for which the source is empty, that is, source == '' ''. Calculate how many reviews are posted on each different client. What is the most popular source? What can that mean for your business?			Bonus: use Python to find the percentage of reviews that is posted on each client (up to +5 pts)
# - **Most popular cars and most active renters.** What are the IDs of the 10 cars with the most reviews? What are the IDs of the 10 renters who gave the most ratings?						Bonus: use Python to create a column with each car’s rank: 1 → car with most reviews, 2 → car with second most reviews, and so on. (up to +5 pts)
# - **Review volume each month:** How many reviews were posted each month? How could you explain the pattern that you observe?

# %% [markdown]
# **4. Vizualization** (30 points)
# - **Distribution of ratings.** Make the histogram plotting the distribution of ratings. Save it in a pdf called "ratings_hist.pdf". What do you observe? What is a possible interpretation?				 Bonus: Make the plot as visually pleasing as possible (up to +5 pts)
# - **Evolution of ratings.** Make a plot of the evolution of ratings over time, that plots each month in the x axis, and the average rating score during that month in the y axis. Save your plot in a pdf called "ratings_evolution.pdf". What do you observe? What is a possible interpretation?
# - **Bonus:** For extra points, make the plot as visually pleasing as possible. (up to +5 pts)

# %% [markdown]
# # Deliverables and grading
#
# Submit the following on blackboard:
#
# **1. your Python code (submission format: only .py or .ipynb files accepted).**
#
# Note: The submitted code has to do *something* for you to receive a non-zero grade for this homework. Please only submit a single clearly-commented .py or .ipynb file
#
# **2. a report outlining the results of your analysis (submission format: only .pdf files accepted).**
#
# Note: In creating the report, keep in mind that the goal of this assignment is to simulate a situation where you report your results to the C-suite. Toward that end, good reports are not unnecessarily lengthy, but rather present the results of the analyses through succinct wording and great figures, as appropriate.
#
# **Collaboration**
#
# You are free to talk to other students about this assignment and help one another. In fact, I encourage you to do so -- peer learning is a powerful learning tool. However, this is not a group assignment. This means that you have to write your own python scripts, and create your own report. If you have any questions, please read course policies #5 and #7 in the syllabus; if you still have questions, contact the instructor!
