# %% [markdown]
# ---
#
# ### 🎓 **Professor**: Apostolos Filippas
#
# ### 📘 **Class**: AI and Data-Driven Marketplaces
#
# ### 📋 **Topic**: Your first script
#
# 🚫 **Note**: You are not allowed to share the contents of this notebook with anyone outside this class without written permission by the professor.
#
# ---

# %% [markdown]
# > **Before you begin:** [Update your course files and Python environment safely.](https://github.com/apostolosfilippas/ma/blob/main/BEFORE_YOU_BEGIN.md)

# %%
# This is the first script for this class
# You are supposed to download, open and run it!
print("Never pay more than 20 bucks for a computer game 🐒")

# %% [markdown]
# If you get an error, close the notebook and open a terminal in the course folder. Run `uv sync`, then reopen the notebook and select the Python interpreter inside `.venv`.
#
# The course environment already includes the notebook kernel. Do not install packages directly from the notebook.

# %%
# Course packages are installed when you run `uv sync` in the terminal.

# %% [markdown]
# Then try to run the first cell again!
